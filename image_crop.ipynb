# %%
#best for word seg

import cv2
import numpy as np 
import matplotlib.pyplot as plt

img = cv2.imread('hand.jpg')
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# gray = cv2.medianBlur(gray,5)
plt.imshow(gray,cmap='gray')

# %%
thresh = cv2.adaptiveThreshold(gray,255,1,1,11,2)
thresh_color = cv2.cvtColor(thresh,cv2.COLOR_GRAY2BGR)
thresh = cv2.medianBlur(thresh,5)

plt.imshow(thresh,cmap='gray')

# %%
thresh = cv2.dilate(thresh,None,iterations = 3)
thresh = cv2.erode(thresh,None,iterations = 2)
# kernel = np.ones((5,5),np.float32)/25
# # dst = cv2.filter2D(thresh,-1,kernel)
thresh = cv2.medianBlur(thresh,5)
plt.imshow(thresh,cmap='gray')

# %%
contours,hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
i =2
for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
    
    if (w+h)>90:
        print(x,y,w,h)
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
#         cv2.rectangle(thresh_color,(x,y),(x+w,y+h),(0,255,0),2)
        image = img[y:y+h,x:x+w]
        cv2.imwrite('hand'+str(i)+'.jpg',image)
        i+=1
                    
    
# cv2.imshow('img',img)
cv2.imwrite('hand1.jpg',img)
# cv2.imshow('res',thresh_color)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img)
# Out:
# 1272 1136 112 99
# 2312 1130 39 166
# 221 1088 600 133
# 1036 1050 491 194
# 1773 1047 415 206
# 1248 854 123 49
# 1490 835 108 90
# 1432 833 34 86
# 1370 827 41 85
# 3086 820 35 144
# 594 819 29 86
# 1294 805 341 12
# 551 797 431 116
# 1946 749 592 166
# 2738 724 276 235
# 643 709 231 101
# 185 700 368 239
# 1795 615 208 70
# 3016 507 37 128
# 1794 502 575 135
# 1070 496 402 124
# 2648 424 293 211
# 270 337 539 245

# %%
# plt.imshow(thresh_color)

# %%
#for character seg

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

img = cv2.imread('hand_nep.jpg')
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# gray = cv2.medianBlur(gray,5)
plt.imshow(gray,cmap='gray')

# %%
# thresh = cv2.adaptiveThreshold(gray,255,1,1,11,2)
ret,thresh = cv2.threshold(gray,120,255,cv2.THRESH_BINARY)
# thresh_color = cv2.cvtColor(thresh,cv2.COLOR_GRAY2BGR)
# thresh_color = cv2.medianBlur(thresh,5)

plt.imshow(thresh,cmap='gray')

# %%
thresh = cv2.dilate(thresh,None,iterations = 3)
thresh = cv2.erode(thresh,None,iterations = 2)
# # kernel = np.ones((5,5),np.float32)/25
# # # # dst = cv2.filter2D(thresh,-1,kernel)
thresh = cv2.medianBlur(thresh,5)
plt.imshow(thresh,cmap='gray')

# %%
contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
i =0
for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
#     print(x,y,w,h)
    if (w+h)>40:
        print(x,y,w,h)
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
#     cv2.rectangle(thresh_color,(x,y),(x+w,y+h),(0,255,0),2)
        image = img[y:y+h,x:x+w]
        cv2.imwrite('hand_ne'+str(i)+'.jpg',image)
    i+=1
                    
# cv2.imshow('img',img)
cv2.imwrite('hand_nep_o.jpg',img)
# cv2.imshow('res',thresh_color)
# cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(img)
# Out:
# 0 0 575 135
# 41 115 75 19
# 228 14 116 84
# 2 14 175 98
# 11 57 76 23
# 4 14 58 11
# 378 11 122 88
# 519 9 48 102
